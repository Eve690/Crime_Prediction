# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv ("Boston dataset.csv")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3057: DtypeWarning: Columns (0,2,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.describe()
# Out:
#         OFFENSE_CODE           YEAR          MONTH           HOUR  \
# count  525575.000000  525575.000000  525575.000000  525575.000000
# mean     2332.260663    2017.591973       6.694575      13.073356
# std      1182.734163       1.566007       3.313055       6.350834
# min       111.000000    2015.000000       1.000000       0.000000
# 25%      1102.000000    2016.000000       4.000000       9.000000
# 50%      3005.000000    2018.000000       7.000000      14.000000
# 75%      3201.000000    2019.000000       9.000000      18.000000
# max      3831.000000    2020.000000      12.000000      23.000000
#
#                  Lat           Long
# count  495821.000000  495821.000000
# mean       42.240681     -70.952056
# std         1.872682       3.029333
# min        -1.000000     -71.203312
# 25%        42.296852     -71.097466
# 50%        42.325024     -71.077734
# 75%        42.348288     -71.062535
# max        42.395042       0.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525575 entries, 0 to 525574
# Data columns (total 17 columns):
# INCIDENT_NUMBER        525575 non-null object
# OFFENSE_CODE           525575 non-null int64
# OFFENSE_CODE_GROUP     426839 non-null object
# OFFENSE_DESCRIPTION    525575 non-null object
# DISTRICT               523113 non-null object
# REPORTING_AREA         525575 non-null object
# SHOOTING               100482 non-null object
# OCCURRED_ON_DATE       525575 non-null object
# YEAR                   525575 non-null int64
# MONTH                  525575 non-null int64
# DAY_OF_WEEK            525575 non-null object
# HOUR                   525575 non-null int64
# UCR_PART               426729 non-null object
# STREET                 504386 non-null object
# Lat                    495821 non-null float64
# Long                   495821 non-null float64
# Location               525575 non-null object
# dtypes: float64(2), int64(4), object(11)
# memory usage: 68.2+ MB

# %%
df.isnull().any()
# Out:
# INCIDENT_NUMBER        False
# OFFENSE_CODE           False
# OFFENSE_CODE_GROUP      True
# OFFENSE_DESCRIPTION    False
# DISTRICT                True
# REPORTING_AREA         False
# SHOOTING                True
# OCCURRED_ON_DATE       False
# YEAR                   False
# MONTH                  False
# DAY_OF_WEEK            False
# HOUR                   False
# UCR_PART                True
# STREET                  True
# Lat                     True
# Long                    True
# Location               False
# dtype: bool

# %%
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP        OFFENSE_DESCRIPTION  \
# 0       TESTTEST2           423                NaN       ASSAULT - AGGRAVATED
# 1       S97333701          3301                NaN             VERBAL DISPUTE
# 2       S47513131          2647                NaN  THREATS TO DO BODILY HARM
# 3       I92102201          3301                NaN             VERBAL DISPUTE
# 4       I92097173          3115                NaN         INVESTIGATE PERSON
#
#    DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0  External                       0  2019-10-16 00:00:00  2019     10
# 1        C6            915        0  2020-07-18 14:34:00  2020      7
# 2       E18            530        0  2020-06-24 10:15:00  2020      6
# 3       E13            583        0  2019-12-20 03:08:00  2019     12
# 4       C11            355        0  2019-10-23 00:00:00  2019     10
#
#   DAY_OF_WEEK  HOUR UCR_PART          STREET        Lat       Long  \
# ...

# %%
df.drop(columns='UCR_PART').head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP        OFFENSE_DESCRIPTION  \
# 0       TESTTEST2           423                NaN       ASSAULT - AGGRAVATED
# 1       S97333701          3301                NaN             VERBAL DISPUTE
# 2       S47513131          2647                NaN  THREATS TO DO BODILY HARM
# 3       I92102201          3301                NaN             VERBAL DISPUTE
# 4       I92097173          3115                NaN         INVESTIGATE PERSON
#
#    DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0  External                       0  2019-10-16 00:00:00  2019     10
# 1        C6            915        0  2020-07-18 14:34:00  2020      7
# 2       E18            530        0  2020-06-24 10:15:00  2020      6
# 3       E13            583        0  2019-12-20 03:08:00  2019     12
# 4       C11            355        0  2019-10-23 00:00:00  2019     10
#
#   DAY_OF_WEEK  HOUR          STREET        Lat       Long  \
# ...

# %%
Y=df.dropna()

# %%
df.isnull().any()
df.head()
# Out:
#   INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP        OFFENSE_DESCRIPTION  \
# 0       TESTTEST2           423                NaN       ASSAULT - AGGRAVATED
# 1       S97333701          3301                NaN             VERBAL DISPUTE
# 2       S47513131          2647                NaN  THREATS TO DO BODILY HARM
# 3       I92102201          3301                NaN             VERBAL DISPUTE
# 4       I92097173          3115                NaN         INVESTIGATE PERSON
#
#    DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE  YEAR  MONTH  \
# 0  External                       0  2019-10-16 00:00:00  2019     10
# 1        C6            915        0  2020-07-18 14:34:00  2020      7
# 2       E18            530        0  2020-06-24 10:15:00  2020      6
# 3       E13            583        0  2019-12-20 03:08:00  2019     12
# 4       C11            355        0  2019-10-23 00:00:00  2019     10
#
#   DAY_OF_WEEK  HOUR UCR_PART          STREET        Lat       Long  \
# ...

# %%
Y
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE        OFFENSE_CODE_GROUP  \
# 909         I192077645          2662                Ballistics
# 910         I192077645           413        Aggravated Assault
# 922         I192077627           413        Aggravated Assault
# 2816        I192075578           413        Aggravated Assault
# 3438        I192074923          1402                 Vandalism
# 3439        I192074923           413        Aggravated Assault
# 3719        I192074613          3125           Warrant Arrests
# 3720        I192074613           111                  Homicide
# 4212        I192074077           413        Aggravated Assault
# 5206        I192072998           413        Aggravated Assault
# 6598        I192071513           413        Aggravated Assault
# 9039        I192068834           413        Aggravated Assault
# 9046        I192068826           413        Aggravated Assault
# 9047        I192068826           413        Aggravated Assault
# ...

# %%
Y.isnull().any()
# Out:
# INCIDENT_NUMBER        False
# OFFENSE_CODE           False
# OFFENSE_CODE_GROUP     False
# OFFENSE_DESCRIPTION    False
# DISTRICT               False
# REPORTING_AREA         False
# SHOOTING               False
# OCCURRED_ON_DATE       False
# YEAR                   False
# MONTH                  False
# DAY_OF_WEEK            False
# HOUR                   False
# UCR_PART               False
# STREET                 False
# Lat                    False
# Long                   False
# Location               False
# dtype: bool

# %%
# Which year had more crimes committed in Boston?
df['YEAR'].mode()
# Out:
# 0    2017
# dtype: int64

# %%
#Not advisable
df.YEAR.mode()
# Out:
# 0    2017
# dtype: int64

# %%
crimerateperyear=df['YEAR'].value_counts()

# %%
crimerateperyear.plot.bar()

# %%
crimerateperyear.plot.area()

# %%
# What days of the week have more crime rates?

# %%
crimerateperweek=df['DAY_OF_WEEK'].value_counts()

# %%
crimerateperweek
# Out:
# Friday       79911
# Wednesday    77174
# Thursday     76385
# Tuesday      76040
# Monday       75477
# Saturday     73937
# Sunday       66651
# Name: DAY_OF_WEEK, dtype: int64

# %%
df['DAY_OF_WEEK'].mode()
# Out:
# 0    Friday
# dtype: object

# %%
crimerateperweek.plot.bar()

# %%
#  What streets of Boston are safer than others?

# %%
Y.head()
# Out:
#      INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 909       I192077645          2662          Ballistics
# 910       I192077645           413  Aggravated Assault
# 922       I192077627           413  Aggravated Assault
# 2816      I192075578           413  Aggravated Assault
# 3438      I192074923          1402           Vandalism
#
#                  OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 909        BALLISTICS EVIDENCE/FOUND       B2            295        Y
# 910   ASSAULT - AGGRAVATED - BATTERY       B2            295        Y
# 922   ASSAULT - AGGRAVATED - BATTERY      C11            344        Y
# 2816  ASSAULT - AGGRAVATED - BATTERY       B3            457        Y
# 3438                       VANDALISM       B2            326        Y
#
#          OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  UCR_PART  \
# 909   2019-09-26 02:38:00  2019      9    Thursday     2  Part Two
# 910   2019-09-26 02:38:00  2019      9    Thursday     2  Part One
# ...

# %%
df['STREET'].value_counts().nsmallest()
# Out:
# 9 AVE          1
# BLACKFALCON    1
# EDWARDS        1
# 4TH            1
# WINTHROP PD    1
# Name: STREET, dtype: int64

# %%
df=np.array('STREET')

# %%
np.count_nonzero(df==1)
# Out:
# 0
